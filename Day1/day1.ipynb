# %%
print("Hello")
# Out:
# Hello

# %%
print(10 + 10)
print( 39 + 76)
# Out:
# 20
# 115

# %%
# we need a tool that can work with csv and excel files in python : pandas (panel data sheet)

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/techficent/Introduction-To-ML/main/AAPL.csv")

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2016-04-11   27.242500   27.652500   27.207500   27.254999   25.350115
# 1     2016-04-12   27.334999   27.625000   27.165001   27.610001   25.680305
# 2     2016-04-13   27.700001   28.084999   27.700001   28.010000   26.052345
# 3     2016-04-14   27.905001   28.097500   27.832500   28.025000   26.066298
# 4     2016-04-15   28.027500   28.075001   27.432501   27.462500   25.543112
# ...          ...         ...         ...         ...         ...         ...
# 1253  2021-04-01  123.660004  124.180000  122.489998  123.000000  123.000000
# 1254  2021-04-05  123.870003  126.160004  123.070000  125.900002  125.900002
# 1255  2021-04-06  126.500000  127.129997  125.650002  126.209999  126.209999
# 1256  2021-04-07  125.830002  127.919998  125.139999  127.900002  127.900002
# 1257  2021-04-08  128.949997  130.389999  128.520004  130.360001  130.360001
#
#          Volume
# 0     117630000
# ...

# %%
local_data = pd.read_csv(r"/home/harshit/Desktop/IntroductionToML/Loan_Status_Classification.csv")
local_data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         0        1           1          0              0             6608
# 1         0        1           2          0              0             4226
# 2         1        1           0          1              0             3167
# 3         0        0           0          1              1             6950
# 4         0        1           0          1              0             3993
# ..      ...      ...         ...        ...            ...              ...
# 293       1        0           0          1              0             3846
# 294       0        0           0          1              0             2435
# 295       0        0           2          1              0             4923
# 296       0        1           3          0              0             2071
# 297       1        0           0          1              0             2378
#
# ...

# %%
loan_data = pd.read_csv("https://raw.githubusercontent.com/techficent/Introduction-To-ML/main/Loan_Status_Classification.csv")
loan_data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         0        1           1          0              0             6608
# 1         0        1           2          0              0             4226
# 2         1        1           0          1              0             3167
# 3         0        0           0          1              1             6950
# 4         0        1           0          1              0             3993
# ..      ...      ...         ...        ...            ...              ...
# 293       1        0           0          1              0             3846
# 294       0        0           0          1              0             2435
# 295       0        0           2          1              0             4923
# 296       0        1           3          0              0             2071
# 297       1        0           0          1              0             2378
#
# ...

# %%
loan_data.describe()
# Out:
#            Gender     Married  Dependents   Education  Self_Employed  \
# count  298.000000  298.000000  298.000000  298.000000     298.000000
# mean     0.177852    0.627517    0.721477    0.788591       0.134228
# std      0.383032    0.484279    0.987945    0.408995       0.341471
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%      0.000000    0.000000    0.000000    1.000000       0.000000
# 50%      0.000000    1.000000    0.000000    1.000000       0.000000
# 75%      0.000000    1.000000    1.000000    1.000000       0.000000
# max      1.000000    1.000000    3.000000    1.000000       1.000000
#
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       298.000000         298.000000  298.000000        298.000000
# mean       5351.265101        1673.026846  143.560403        339.986577
# std        6306.080712        2892.404818   80.395182         70.866877
# ...

# %%
# select ApplicantIncome,CoApplicantIncome from loan_data

# %%
loan_data.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_data[            ["ApplicantIncome","CoapplicantIncome"]                     ]
# Out:
#      ApplicantIncome  CoapplicantIncome
# 0               6608                  0
# 1               4226               1040
# 2               3167               2283
# 3               6950                  0
# 4               3993               3274
# ..               ...                ...
# 293             3846                  0
# 294             2435                  0
# 295             4923                  0
# 296             2071                754
# 297             2378                  0
#
# [298 rows x 2 columns]

# %%
loan_data[  ["ApplicantIncome","LoanAmount"]   ].mean()
# Out:
# ApplicantIncome    5351.265101
# LoanAmount          143.560403
# dtype: float64

# %% [markdown]
# # missing values count per column

# %%
loan_data.loc[    11, ["ApplicantIncome"]     ].isna()
# Out:
# ApplicantIncome    False
# Name: 11, dtype: bool

# %% [markdown]
# python: programming language
# vs code : editor (a place to type code) (alternatives : jupyter, Pycharm, DataSpell, etc)
# Python extension for VS Code (ability to work in python better. Auto complete, error highlights, etc)
# libraries/packages : collection of readymade coding functionalities
#             -pandas, polars
#             -seaborn or plotly
#             -scikit-learn (machine learning)
#             -Tensorflow (library of neural networks)

# %%
import plotly.express as px

# %%
# correlation between applicant Income and LoanAmount

# %%
loan_data[    ["ApplicantIncome","LoanAmount"]    ].corr()
# Out:
#                  ApplicantIncome  LoanAmount
# ApplicantIncome         1.000000    0.517302
# LoanAmount              0.517302    1.000000

# %%
px.scatter(
    data_frame=loan_data,
    x="ApplicantIncome",
    y="LoanAmount",
    facet_col="Married"
)

# %%
# a graph to show change in data values over a period of time

# %%
px.line(
    data_frame=df,
    x="Date",
    y="Open"
)

# %% [markdown]
# Classify loan applications received into Loan accepted and loan rejected!
#
#
# Note: data for the last 1000 loan applications (labelled data records)

# %% [markdown]
# 30 techniques in ML

# %% [markdown]
# ### supervised learning:
#     i) Logistic Regression (logit models)
#     ii) Decision Trees
#     iii) Naive Bayes
#     iv) Random Forest

# %% [markdown]
# ### Steps for Supervised Learning
#
#
# 1) Load the data: source & collect data and then make a merged data frame!
# 2) analyse & clean the data (pre-processing the data) : correct the problems in the data and understand it!
# 3) Features & target!!!! : identify and separate
#     ### Recurssive FE, correlation, feature importance, etc
#     target : is a column(attribute) that is to be predicted by the model!
#     features: all columns to be used to make a judgement (prediction )
#
# 4) Splitting of data : separate into training & validation set (testing set)
#
# 5) training of model :

# %%
# exam: same question? OR different questions of the same pattern?

# %%
loan_data
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         0        1           1          0              0             6608
# 1         0        1           2          0              0             4226
# 2         1        1           0          1              0             3167
# 3         0        0           0          1              1             6950
# 4         0        1           0          1              0             3993
# ..      ...      ...         ...        ...            ...              ...
# 293       1        0           0          1              0             3846
# 294       0        0           0          1              0             2435
# 295       0        0           2          1              0             4923
# 296       0        1           3          0              0             2071
# 297       1        0           0          1              0             2378
#
# ...
