# %% [markdown]
# Artificial Intelligence
#
# --------> last 5 years of a bank's performance
# --------> predict/analyse of trend of bank performance for next 5 years
#
#
#
# 1) Chatbots, google assitant, alexa
#
# 2) Credit Risk prediction
#
# 3) Credit card transaction is fraud or not
#
#
# Artificial Intelligence (speech recognition, image classification, self-driving, AI)
# |
# |
# |
# Machine Learning (predict, classify or clustering) [tabulated data for achieving numeric output!]
# |
# |
# |
# Deep learning (data that is not linearly separable!)
# ---------> Neural Network!
#
#
#
#
#
#
#
#
#
#
#
# Supervised learning
# Problem 1: Identify whether a transaction is fraudulent or not! (YES OR NO) [classification type of supervised problem]
#
# Amount               Limit              Fraud
# 100000                100000            YES
# 200000               120000000              NO
#
#
# 3456                100000              ???????
#
#
# Problem 2: Predict the value of a customer's portfolio based on factors such stocks, duration, amount (a real-value) [predictive type of supervised of learning]
#
# StocksCOunt             Duration of investment(in Months)            Value_of_portfolio
# 10                       24                                                 10000000000000
# 12                       4                                                  890000000
#
#
# 40 stocks                 36                                           ??????????
#
#
# Unsupervised because the expected target column is not part of the dataset
# Problem 3: Classify customers into HIGH RISK AND LOW RISK CATEGORIES
# No data for categories available in the databse
#
#
# Age          Income          AverageMonthlyTransaction
# 28           780000             12000
# 29           10000000           11000
# 30           10220000            1111

# %% [markdown]
# credit card customers
#
# time amount duration

# %% [markdown]
# 1 + 1 = 2

# %% [markdown]
# softwares that think like humans : artificial intelligence
#
#
#
# one subcategory of AI : ML (tabular data and statistical formula applied )
#
# |
# |
# |
# NLP

# %%
scikit-learn


Pytorch & Tensorflow


GPL  MIT

# %% [markdown]
# # An Introduction to Machine Learning
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Machine learning (ML) is a category of an algorithm that allows software applications to become more accurate in predicting outcomes without being explicitly programmed. The basic premise of machine learning is to build algorithms that can receive input data and use statistical analysis to predict an output while updating outputs as new data becomes available.

# %% [markdown]
# The goal of machine learning generally is to understand the structure of data and fit that data into models that can be understood and utilized by people.
#
#
# In machine learning, tasks are generally classified into broad categories. These categories are based on how learning is received or how feedback on the learning is given to the system developed.
#
# ![image.png](attachment:image.png)
#
# # Supervised learning
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# It trains algorithms based on example input and output data that is labeled by humans
#
#
# # Unsupervised learning
#
# ![image-3.png](attachment:image-3.png)
#
#
# It provides the algorithm with no labeled data in order to allow it to find structure within its input data.
#
# # Reinforcement Learning
#
# ![image-4.png](attachment:image-4.png)
#
#
# It is a type of dynamic programming that trains algorithms using a system of reward and punishment.
